# %%
import os
from pathlib import Path

repo_path = Path.home() / "HelpHerInvest"
os.chdir(repo_path)
print(f"Current working directory: {Path.cwd()}")
# Out:
# Current working directory: /home/jupyter-guotq/HelpHerInvest

# %%
import os
from pathlib import Path

repo_path = Path.home() / "HelpHerInvest"
os.chdir(repo_path)
print(f"Current working directory: {Path.cwd()}")
# Out:
# Current working directory: /home/jupyter-guotq/HelpHerInvest

# %%
import pandas as pd
from pathlib import Path

def find_repo_root(start_path=None):
    p = Path(start_path or Path.cwd()).resolve()
    for parent in [p] + list(p.parents):
        if (parent / ".git").exists():
            return parent
    return p

# Prepare to save in the repo’s Data directory
REPO_ROOT = find_repo_root()
DATA_DIR = REPO_ROOT / "Data"
DATA_DIR.mkdir(parents=True, exist_ok=True)

rows = [
    {
        "symbol": "AAPL",
        "company_name": "Apple Inc.",
        "sector": "Technology",
        "industry": "Consumer Electronics",
        "exchange": "NASDAQ",
    },
    {
        "symbol": "MSFT",
        "company_name": "Microsoft Corp.",
        "sector": "Technology",
        "industry": "Software—Infrastructure",
        "exchange": "NASDAQ",
    },
    {
        "symbol": "XOM",
        "company_name": "Exxon Mobil Corp.",
        "sector": "Energy",
        "industry": "Oil & Gas Integrated",
        "exchange": "NYSE",
    },
]

output_path = DATA_DIR / "stock_symbols_tongyu_testing3.csv.zip"

df_base = pd.DataFrame(rows)
df_base.to_csv(output_path, index=False, compression="zip")

print(df_base)
print(f"\nSaved file: {output_path}")
# Out:
#   symbol       company_name      sector                 industry exchange
# 0   AAPL         Apple Inc.  Technology     Consumer Electronics   NASDAQ
# 1   MSFT    Microsoft Corp.  Technology  Software—Infrastructure   NASDAQ
# 2    XOM  Exxon Mobil Corp.      Energy     Oil & Gas Integrated     NYSE
#
# Saved file: /home/jupyter-guotq/HelpHerInvest/Data/stock_symbols_tongyu_testing3.csv.zip

# %%
# Confirm the file is in the Data folder
# !ls -lh Data | grep stock_symbols_tongyu_testing3.csv.zip

# See repository status (shows uncommitted changes)
# !git status
# Out:
# -rw-r--r-- 1 jupyter-guotq jupyter-guotq  339 Jan 30 00:39 stock_symbols_tongyu_testing3.csv.zip
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Data/stock_symbols_tongyu_testing3.csv.zip
# 	Week 01 Identify the Problem Statement and Dataset/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# 	Week 01 Identify the Problem Statement and Dataset/.ipynb_checkpoints/exploratory_analysis_v2-checkpoint.py
# 	Week 01 Identify the Problem Statement and Dataset/Untitled.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# Stage the new file
# !git add Data/stock_symbols_tongyu_testing3.csv.zip

# Commit (edit the message if needed)
# !git commit -m "Add stock_symbols_tongyu_testing3 data file"

# Push to GitHub (enter your GitHub username and PAT when prompted)
# !git push
# Out:
# [main c2858c1] Add stock_symbols_tongyu_testing3 data file
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Data/stock_symbols_tongyu_testing3.csv.zip
# Username for 'https://github.com': ^C
