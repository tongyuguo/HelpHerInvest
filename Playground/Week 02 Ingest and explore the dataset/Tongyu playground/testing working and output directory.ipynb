# %%
# 1) Go to repo
# %cd /home/jupyter-guotq/HelpHerInvest
# Out:
# /home/jupyter-guotq/HelpHerInvest

# %%
# 2) Sync latest from GitHub before editing
# !git pull --rebase origin main

# 3) Do your data work here (create/modify files)
# Out:
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 8 (delta 5), reused 8 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (8/8), 2.54 KiB | 519.00 KiB/s, done.
# From https://github.com/tongyuguo/HelpHerInvest
#  * branch            main       -> FETCH_HEAD
#    c807418..e7ffd2b  main       -> origin/main
# Updating c807418..e7ffd2b
# Fast-forward
#  .../testing working and output directory.ipynb     | 174 +++++++++++++++++++--
#  1 file changed, 158 insertions(+), 16 deletions(-)

# %%
from pathlib import Path
import pandas as pd

rows = [
    {
        "symbol": "AAPL",
        "company_name": "Apple Inc.",
        "sector": "Technology",
        "industry": "Consumer Electronics",
        "exchange": "NASDAQ",
    },
    {
        "symbol": "MSFT",
        "company_name": "Microsoft Corp.",
        "sector": "Technology",
        "industry": "Software—Infrastructure",
        "exchange": "NASDAQ",
    },
    {
        "symbol": "XOM",
        "company_name": "Exxon Mobil Corp.",
        "sector": "Energy",
        "industry": "Oil & Gas Integrated",
        "exchange": "NYSE",
    },
]

# JupyterHub repo path
repo_root = Path("/home/jupyter-guotq/HelpHerInvest")

df = pd.DataFrame(rows)

out_path = repo_root / "Data" / "testing 2.csv"
out_path.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(out_path, index=False)

print("saved:", out_path)
# Out:
# saved: /home/jupyter-guotq/HelpHerInvest/Data/testing 2.csv

# %%
# 4) Check what changed
# !git status -sb
# Out:
# ## main...origin/main
# ?? "Data/testing 2.csv"

# %%
# 5) Stage + commit
# !git add -A
# !git commit -m "hopefull final testing of working and output directory"
# Out:
# [main c552c7d] hopefull final testing of working and output directory
#  1 file changed, 4 insertions(+)
#  create mode 100644 Data/testing 2.csv

# %%
# 6) Push
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 353 bytes | 353.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/tongyuguo/HelpHerInvest.git
#    e7ffd2b..c552c7d  main -> main
