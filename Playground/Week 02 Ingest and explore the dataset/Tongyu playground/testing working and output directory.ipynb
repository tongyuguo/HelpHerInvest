# %%
from pathlib import Path
import pandas as pd

rows = [
    {
        "symbol": "AAPL",
        "company_name": "Apple Inc.",
        "sector": "Technology",
        "industry": "Consumer Electronics",
        "exchange": "NASDAQ",
    },
    {
        "symbol": "MSFT",
        "company_name": "Microsoft Corp.",
        "sector": "Technology",
        "industry": "Software—Infrastructure",
        "exchange": "NASDAQ",
    },
    {
        "symbol": "XOM",
        "company_name": "Exxon Mobil Corp.",
        "sector": "Energy",
        "industry": "Oil & Gas Integrated",
        "exchange": "NYSE",
    },
]

# JupyterHub repo path
repo_root = Path("/home/jupyter-guotq/HelpHerInvest")

df = pd.DataFrame(rows)

out_path = repo_root / "Data" / "sample_companies.csv"
out_path.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(out_path, index=False)

print("saved:", out_path)
# Out:
# saved: /home/jupyter-guotq/HelpHerInvest/Data/sample_companies.csv

# %%
# !git add Data/sample_companies.csv
# !git commit -m "Add sample companies CSV"
# !git pull --rebase
# !git push
# Out:
# [main 2a1d9c9] Add sample companies CSV
#  1 file changed, 4 insertions(+)
#  create mode 100644 Data/sample_companies.csv
# There is no tracking information for the current branch.
# Please specify which branch you want to rebase against.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main
#
# fatal: The current branch main has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin main
#
# To have this happen automatically for branches without a tracking
# upstream, see 'push.autoSetupRemote' in 'git help config'.

# %%
# !git pull --rebase origin main
# !git push
# Out:
# From https://github.com/tongyuguo/HelpHerInvest
#  * branch            main       -> FETCH_HEAD
# Successfully rebased and updated refs/heads/main.
# fatal: The current branch main has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin main
#
# To have this happen automatically for branches without a tracking
# upstream, see 'push.autoSetupRemote' in 'git help config'.

# %%
# %cd /home/jupyter-guotq/HelpHerInvest
# !git status -sb
# !git push -u origin main
# Out:
# /home/jupyter-guotq/HelpHerInvest
# ## main
# ?? Data/sample_companies.csv
# To https://github.com/tongyuguo/HelpHerInvest.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/tongyuguo/HelpHerInvest.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. If you want to integrate the remote changes,
# hint: use 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git push --set-upstream origin main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 551 bytes | 551.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/tongyuguo/HelpHerInvest.git
#    8f8e2f4..c807418  main -> main
# branch 'main' set up to track 'origin/main'.

# %%
git add -A
git commit -m "WIP: update files"
git push

# %%
# !git pull --rebase origin main
# !git push
# Out:
# From https://github.com/tongyuguo/HelpHerInvest
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Everything up-to-date
